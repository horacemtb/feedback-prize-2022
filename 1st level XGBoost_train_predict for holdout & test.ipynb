# %% [markdown]
# In this notebook, we will train a first-level XGBoost model using descriptive text features, FastText discourse embeddings, and TF-IDF + UMAP essay embeddings obtained during the preparation stage.
#
# We will then apply the model to generate first-level predictions for the holdout and test sets. These predictions will serve as one of the features for training a second-level model.

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 10.7 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 12.3 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import json
import pickle
import os
import joblib

import pandas as pd
import numpy as np

from sklearn.metrics import precision_score, recall_score, f1_score, log_loss
from sklearn.preprocessing import LabelEncoder

import xgboost as xgb
import optuna

from tqdm import tqdm
from collections import Counter

# %%
BASIC_PATH = '/content/gdrive/MyDrive/ML/projects/feedback-prize/'
MODEL_PATH = '1st_level_models/'
SAVE_TRANSFORMED_DATASETS = '1st_level_transformed_data/'
SAVE_DATASETS_FOLDER = '1st_level_preds/'

# %% [markdown]
# Load the preprocessed datasets for training.

# %%
train_df = pd.read_csv(BASIC_PATH+SAVE_TRANSFORMED_DATASETS+'train_df_transformed.csv')
val_df = pd.read_csv(BASIC_PATH+SAVE_TRANSFORMED_DATASETS+'val_df_transformed.csv')
holdout_data = pd.read_csv(BASIC_PATH+SAVE_TRANSFORMED_DATASETS+'holdout_data_transformed.csv')
test_data = pd.read_csv(BASIC_PATH+SAVE_TRANSFORMED_DATASETS+'test_data_transformed.csv')

# %%
train_df.head()
# Out:
#    discourse_id      essay_id discourse_type  target  discourse_len  \
# 0  ed3a833a2f49  013B9AA6B9DB           Lead       0             28
# 1  c2203a58aa5c  013B9AA6B9DB       Position       0            101
# 2  804266501124  013B9AA6B9DB       Evidence       0            190
# 3  9e0d25faca07  013B9AA6B9DB   Counterclaim       0             65
# 4  7a01d9cb379a  013B9AA6B9DB       Rebuttal       2             16
#
#    discourse_num_long_words  discourse_num_short_words  discourse_noun_count  \
# 0                  0.000000                   0.500000              0.166667
# 1                  0.100000                   0.650000              0.100000
# 2                  0.108108                   0.567568              0.243243
# 3                  0.153846                   0.307692              0.153846
# 4                  0.000000                   1.000000              0.000000
#
#    discourse_adj_count  discourse_pnoun_count  ...  umap_emb_54  umap_emb_55  \
# 0             0.000000               0.166667  ...     5.197482     4.790548
# 1             0.000000               0.000000  ...     5.197482     4.790548
# 2             0.054054               0.027027  ...     5.197482     4.790548
# 3             0.076923               0.076923  ...     5.197482     4.790548
# 4             0.000000               0.000000  ...     5.197482     4.790548
#
#    umap_emb_56  umap_emb_57  umap_emb_58  umap_emb_59  umap_emb_60  \
# 0     5.558707     4.091189     3.953247     3.980204     4.616942
# 1     5.558707     4.091189     3.953247     3.980204     4.616942
# 2     5.558707     4.091189     3.953247     3.980204     4.616942
# 3     5.558707     4.091189     3.953247     3.980204     4.616942
# 4     5.558707     4.091189     3.953247     3.980204     4.616942
#
#    umap_emb_61  umap_emb_62  umap_emb_63
# 0     6.128882     4.579642     4.220257
# 1     6.128882     4.579642     4.220257
# 2     6.128882     4.579642     4.220257
# 3     6.128882     4.579642     4.220257
# 4     6.128882     4.579642     4.220257
#
# [5 rows x 144 columns]

# %%
COLS_TO_DROP = ['discourse_id', 'essay_id', 'target'] # specify the columns to drop, retaining only the features for the training set.
TARGET = 'target'
CAT_FEATURES = ['discourse_type']

# %% [markdown]
# Preprocess categorical columns for the model.

# %%
train_df[CAT_FEATURES] = train_df[CAT_FEATURES].astype('category')
val_df[CAT_FEATURES] = val_df[CAT_FEATURES].astype('category')
holdout_data[CAT_FEATURES] = holdout_data[CAT_FEATURES].astype('category')
test_data[CAT_FEATURES] = test_data[CAT_FEATURES].astype('category')

# %% [markdown]
# Prepare datasets for XGBoost and set the class weights.

# %%
class_weights = {0: 1, 1: 1.25, 2: 1.75}

# %%
dtrain = xgb.DMatrix(train_df.drop(COLS_TO_DROP, axis = 1),
                     label = train_df[TARGET],
                     enable_categorical = True,
                     weight = train_df[TARGET].map(class_weights))

dval = xgb.DMatrix(val_df.drop(COLS_TO_DROP, axis = 1),
                   label = val_df[TARGET],
                   enable_categorical = True,
                   weight = val_df[TARGET].map(class_weights))

holdout = xgb.DMatrix(holdout_data.drop(COLS_TO_DROP, axis = 1),
                   enable_categorical = True)

test = xgb.DMatrix(test_data.drop(COLS_TO_DROP, axis = 1),
                   enable_categorical = True)

# %% [markdown]
# Configure Optuna optimization and initiate the search for optimal hyperparameters.

# %%
def objective(trial):

    xgb_params = {
        'objective': 'multi:softprob',
        'num_class': 3,
        'eval_metric': 'mlogloss',
        'max_depth': trial.suggest_int('max_depth', 4, 12),
        'min_child_weight': trial.suggest_int('min_child_weight', 6, 30),
        'learning_rate': 0.01,
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0, step = 0.1),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0, step = 0.1),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'alpha': trial.suggest_float('alpha', 0, 3),
        'lambda': trial.suggest_float('lambda', 0, 3),
        'tree_method': 'hist',
        'random_state': 97,
        'verbosity': 1,
        'device': 'cuda'
    }

    model = xgb.train(params = xgb_params,
                      dtrain = dtrain,
                      evals = [(dval, 'validation')],
                      num_boost_round = 2000,
                      early_stopping_rounds = 20,
                      verbose_eval = False)

    return model.best_score

# %%
study = optuna.create_study(direction = 'minimize', study_name = 'XGBoost parameters')
# Out:
# [I 2024-10-06 05:24:16,094] A new study created in memory with name: XGBoost parameters

# %%
def callback(study, trial):
  pbar.update(1)

# %%
N_trials = 200

with tqdm(total = N_trials, desc = "Optuna Optimization", dynamic_ncols = True, bar_format = '{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]') as pbar:
    study.optimize(objective, n_trials = N_trials, callbacks = [callback])
# Out:
# Optuna Optimization:   0%|          | 0/200 [00:00<?][I 2024-10-06 05:25:20,564] Trial 0 finished with value: 0.7155000427302075 and parameters: {'max_depth': 7, 'min_child_weight': 17, 'colsample_bytree': 1.0, 'subsample': 0.7, 'gamma': 1.665081507430091, 'alpha': 2.241160706365798, 'lambda': 2.825595615881582}. Best is trial 0 with value: 0.7155000427302075.
# Optuna Optimization:   0%|          | 1/200 [00:42<2:20:49][I 2024-10-06 05:25:52,503] Trial 1 finished with value: 0.7165400737564436 and parameters: {'max_depth': 8, 'min_child_weight': 26, 'colsample_bytree': 0.7, 'subsample': 0.8, 'gamma': 3.829626175270637, 'alpha': 2.323942974623124, 'lambda': 2.8426622304122864}. Best is trial 0 with value: 0.7155000427302075.
# Optuna Optimization:   1%|          | 2/200 [01:14<1:59:41][I 2024-10-06 05:26:24,997] Trial 2 finished with value: 0.7173134049599011 and parameters: {'max_depth': 6, 'min_child_weight': 18, 'colsample_bytree': 0.7, 'subsample': 0.9, 'gamma': 1.319417712101073, 'alpha': 2.7023621213516593, 'lambda': 0.5632051009859879}. Best is trial 0 with value: 0.7155000427302075.
# Optuna Optimization:   2%|▏         | 3/200 [01:46<1:53:25][I 2024-10-06 05:27:05,360] Trial 3 finished with value: 0.7145537041615336 and parameters: {'max_depth': 11, 'min_child_weight': 7, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.849256903426009, 'alpha': 2.0150582910015054, 'lambda': 2.763295139686344}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   2%|▏         | 4/200 [02:27<2:00:21][I 2024-10-06 05:27:43,858] Trial 4 finished with value: 0.7275389418497205 and parameters: {'max_depth': 11, 'min_child_weight': 15, 'colsample_bytree': 1.0, 'subsample': 1.0, 'gamma': 4.115657079995439, 'alpha': 1.467797054670747, 'lambda': 2.6660054258156833}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   2%|▎         | 5/200 [03:05<2:01:40][I 2024-10-06 05:28:37,837] Trial 5 finished with value: 0.7168501247907877 and parameters: {'max_depth': 9, 'min_child_weight': 23, 'colsample_bytree': 0.6, 'subsample': 1.0, 'gamma': 0.8760830971929773, 'alpha': 0.5155700820782742, 'lambda': 0.23405599508333297}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   3%|▎         | 6/200 [03:59<2:19:14][I 2024-10-06 05:29:03,694] Trial 6 finished with value: 0.7243262261550393 and parameters: {'max_depth': 6, 'min_child_weight': 17, 'colsample_bytree': 1.0, 'subsample': 1.0, 'gamma': 2.6858713158814735, 'alpha': 0.6962665440325009, 'lambda': 1.9171553585215222}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   4%|▎         | 7/200 [04:25<2:00:25][I 2024-10-06 05:29:43,607] Trial 7 finished with value: 0.7158997366510257 and parameters: {'max_depth': 7, 'min_child_weight': 24, 'colsample_bytree': 0.7, 'subsample': 0.6, 'gamma': 0.06361819008759984, 'alpha': 2.4755125115847694, 'lambda': 2.2233921904047125}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   4%|▍         | 8/200 [05:05<2:02:19][I 2024-10-06 05:30:12,215] Trial 8 finished with value: 0.7145904686554956 and parameters: {'max_depth': 7, 'min_child_weight': 18, 'colsample_bytree': 0.7, 'subsample': 0.7, 'gamma': 4.054300173733444, 'alpha': 0.3020285867396988, 'lambda': 0.5332218371551041}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   4%|▍         | 9/200 [05:34<1:52:06][I 2024-10-06 05:30:58,200] Trial 9 finished with value: 0.7163499940825083 and parameters: {'max_depth': 10, 'min_child_weight': 24, 'colsample_bytree': 1.0, 'subsample': 0.5, 'gamma': 3.129103508095441, 'alpha': 1.3091043712144126, 'lambda': 0.297872480311281}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   5%|▌         | 10/200 [06:20<2:02:03][I 2024-10-06 05:31:28,875] Trial 10 finished with value: 0.7178370747614392 and parameters: {'max_depth': 12, 'min_child_weight': 7, 'colsample_bytree': 0.5, 'subsample': 0.5, 'gamma': 4.992566854327986, 'alpha': 1.863781212370852, 'lambda': 1.2427798335935765}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   6%|▌         | 11/200 [06:50<1:53:49][I 2024-10-06 05:31:49,606] Trial 11 finished with value: 0.7203748645843442 and parameters: {'max_depth': 4, 'min_child_weight': 6, 'colsample_bytree': 0.8, 'subsample': 0.7, 'gamma': 4.909204522312297, 'alpha': 0.18080430181114998, 'lambda': 1.0543579814718345}. Best is trial 3 with value: 0.7145537041615336.
# Optuna Optimization:   6%|▌         | 12/200 [07:11<1:38:32][I 2024-10-06 05:32:32,940] Trial 12 finished with value: 0.7138689358064976 and parameters: {'max_depth': 10, 'min_child_weight': 12, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.7925572516465462, 'alpha': 1.0191297002905504, 'lambda': 1.8021385403832997}. Best is trial 12 with value: 0.7138689358064976.
# Optuna Optimization:   6%|▋         | 13/200 [07:54<1:49:14][I 2024-10-06 05:33:24,139] Trial 13 finished with value: 0.7137530503049379 and parameters: {'max_depth': 12, 'min_child_weight': 11, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.303179724832364, 'alpha': 1.0229816032829646, 'lambda': 1.8586732437666844}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:   7%|▋         | 14/200 [08:46<2:03:46][I 2024-10-06 05:34:17,808] Trial 14 finished with value: 0.7145898403622241 and parameters: {'max_depth': 12, 'min_child_weight': 12, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.1614910537891374, 'alpha': 1.1130379338686027, 'lambda': 1.7929933872088797}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:   8%|▊         | 15/200 [09:39<2:15:53][I 2024-10-06 05:35:16,410] Trial 15 finished with value: 0.7138078811116173 and parameters: {'max_depth': 10, 'min_child_weight': 11, 'colsample_bytree': 0.5, 'subsample': 0.9, 'gamma': 2.512727250088711, 'alpha': 0.9356815767048363, 'lambda': 2.265741302755848}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:   8%|▊         | 16/200 [10:38<2:28:33][I 2024-10-06 05:36:11,973] Trial 16 finished with value: 0.7153702997551076 and parameters: {'max_depth': 10, 'min_child_weight': 10, 'colsample_bytree': 0.6, 'subsample': 0.9, 'gamma': 2.5265727261794706, 'alpha': 0.8140633344655507, 'lambda': 2.362173650018129}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:   8%|▊         | 17/200 [11:33<2:34:16][I 2024-10-06 05:37:11,037] Trial 17 finished with value: 0.7174566455680282 and parameters: {'max_depth': 12, 'min_child_weight': 30, 'colsample_bytree': 0.8, 'subsample': 0.9, 'gamma': 2.21167799524831, 'alpha': 1.7089827709017225, 'lambda': 1.4494213591451373}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:   9%|▉         | 18/200 [12:32<2:41:10][I 2024-10-06 05:38:10,370] Trial 18 finished with value: 0.7158772458320584 and parameters: {'max_depth': 9, 'min_child_weight': 11, 'colsample_bytree': 0.5, 'subsample': 0.9, 'gamma': 1.890819923768297, 'alpha': 0.013341979057785114, 'lambda': 2.322308278987911}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:  10%|▉         | 19/200 [13:32<2:45:54][I 2024-10-06 05:38:54,585] Trial 19 finished with value: 0.7148982825548781 and parameters: {'max_depth': 11, 'min_child_weight': 14, 'colsample_bytree': 0.6, 'subsample': 0.6, 'gamma': 3.0838435958864516, 'alpha': 2.9892486903429036, 'lambda': 1.0079846944418864}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:  10%|█         | 20/200 [14:16<2:35:16][I 2024-10-06 05:40:02,934] Trial 20 finished with value: 0.7192676262240122 and parameters: {'max_depth': 9, 'min_child_weight': 9, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 0.5238341808226876, 'alpha': 1.1747315574077128, 'lambda': 2.050754502834234}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:  10%|█         | 21/200 [15:24<2:49:16][I 2024-10-06 05:40:48,540] Trial 21 finished with value: 0.7145507910599476 and parameters: {'max_depth': 10, 'min_child_weight': 13, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.4418192754466244, 'alpha': 0.9961947552823958, 'lambda': 1.7650588711538506}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:  11%|█         | 22/200 [16:10<2:38:24][I 2024-10-06 05:41:25,700] Trial 22 finished with value: 0.7164506255121654 and parameters: {'max_depth': 11, 'min_child_weight': 9, 'colsample_bytree': 0.6, 'subsample': 0.9, 'gamma': 4.500673860762792, 'alpha': 0.8578910708468956, 'lambda': 1.5748227038990112}. Best is trial 13 with value: 0.7137530503049379.
# Optuna Optimization:  12%|█▏        | 23/200 [16:47<2:23:08][I 2024-10-06 05:42:10,175] Trial 23 finished with value: 0.7136247196898892 and parameters: {'max_depth': 10, 'min_child_weight': 15, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.4538525122451804, 'alpha': 1.540957585838027, 'lambda': 1.5393509745825014}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  12%|█▏        | 24/200 [17:32<2:18:46][I 2024-10-06 05:43:05,032] Trial 24 finished with value: 0.7140846337618539 and parameters: {'max_depth': 12, 'min_child_weight': 21, 'colsample_bytree': 0.6, 'subsample': 0.9, 'gamma': 2.752667484147913, 'alpha': 1.5450943039046727, 'lambda': 2.5079135407079467}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  12%|█▎        | 25/200 [18:26<2:24:35][I 2024-10-06 05:43:49,520] Trial 25 finished with value: 0.7181079161067975 and parameters: {'max_depth': 8, 'min_child_weight': 15, 'colsample_bytree': 0.9, 'subsample': 0.8, 'gamma': 2.057779741701145, 'alpha': 0.5920219603044197, 'lambda': 1.4954204414865768}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  13%|█▎        | 26/200 [19:11<2:19:20][I 2024-10-06 05:44:26,847] Trial 26 finished with value: 0.7152747231421611 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 1.0, 'gamma': 3.4250389469000453, 'alpha': 1.3752238793998472, 'lambda': 2.146876951528975}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  14%|█▎        | 27/200 [19:48<2:09:15][I 2024-10-06 05:45:01,902] Trial 27 finished with value: 0.7166472486658065 and parameters: {'max_depth': 11, 'min_child_weight': 15, 'colsample_bytree': 0.5, 'subsample': 0.6, 'gamma': 4.468155197254428, 'alpha': 1.577201817470093, 'lambda': 1.3321580898757057}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  14%|█▍        | 28/200 [20:23<2:00:06][I 2024-10-06 05:45:59,630] Trial 28 finished with value: 0.7150736868304761 and parameters: {'max_depth': 10, 'min_child_weight': 9, 'colsample_bytree': 0.6, 'subsample': 0.9, 'gamma': 2.2520632831305702, 'alpha': 1.9184235301130965, 'lambda': 0.9360299216626313}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  14%|█▍        | 29/200 [21:21<2:12:56][I 2024-10-06 05:46:21,988] Trial 29 finished with value: 0.7192276733610101 and parameters: {'max_depth': 4, 'min_child_weight': 17, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 1.5532359576147239, 'alpha': 0.43905082456537614, 'lambda': 2.019342601153603}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  15%|█▌        | 30/200 [21:43<1:51:31][I 2024-10-06 05:47:20,079] Trial 30 finished with value: 0.718490088575375 and parameters: {'max_depth': 12, 'min_child_weight': 13, 'colsample_bytree': 0.9, 'subsample': 0.8, 'gamma': 2.858635908849489, 'alpha': 1.2593833963764018, 'lambda': 1.6533564978351303}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  16%|█▌        | 31/200 [22:41<2:06:41][I 2024-10-06 05:48:05,228] Trial 31 finished with value: 0.7138910640843255 and parameters: {'max_depth': 10, 'min_child_weight': 11, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.4972495196929776, 'alpha': 1.0186722279065643, 'lambda': 1.8755184025367502}. Best is trial 23 with value: 0.7136247196898892.
# Optuna Optimization:  16%|█▌        | 32/200 [23:27<2:06:05][I 2024-10-06 05:48:42,876] Trial 32 finished with value: 0.7130877900150618 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.641893400788881, 'alpha': 0.9206455351754421, 'lambda': 2.5088221220939406}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  16%|█▋        | 33/200 [24:04<1:59:10][I 2024-10-06 05:49:15,696] Trial 33 finished with value: 0.7131080203041329 and parameters: {'max_depth': 7, 'min_child_weight': 14, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.6883239059907793, 'alpha': 0.8060558545560884, 'lambda': 2.943880186464773}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  17%|█▋        | 34/200 [24:37<1:50:09][I 2024-10-06 05:49:46,371] Trial 34 finished with value: 0.7138556553156392 and parameters: {'max_depth': 7, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.639099305698503, 'alpha': 0.6995181900992296, 'lambda': 2.992686187503338}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  18%|█▊        | 35/200 [25:08<1:41:57][I 2024-10-06 05:50:09,173] Trial 35 finished with value: 0.7153503206561026 and parameters: {'max_depth': 6, 'min_child_weight': 20, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 4.3306989583615465, 'alpha': 1.7036585346678175, 'lambda': 2.5929774633315774}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  18%|█▊        | 36/200 [25:31<1:29:37][I 2024-10-06 05:50:41,988] Trial 36 finished with value: 0.7141410608122196 and parameters: {'max_depth': 8, 'min_child_weight': 13, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 4.048157545387437, 'alpha': 0.7528723391476763, 'lambda': 2.8734305164815694}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  18%|█▊        | 37/200 [26:03<1:29:06][I 2024-10-06 05:51:09,609] Trial 37 finished with value: 0.7160115899379822 and parameters: {'max_depth': 6, 'min_child_weight': 14, 'colsample_bytree': 0.7, 'subsample': 0.6, 'gamma': 3.2382320602013888, 'alpha': 2.1673494440765824, 'lambda': 2.9991567144193056}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  19%|█▉        | 38/200 [26:31<1:24:21][I 2024-10-06 05:51:33,380] Trial 38 finished with value: 0.716811840681405 and parameters: {'max_depth': 5, 'min_child_weight': 18, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.7866728235921583, 'alpha': 1.4462823959351705, 'lambda': 2.47552585645433}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  20%|█▉        | 39/200 [26:55<1:17:49][I 2024-10-06 05:52:05,540] Trial 39 finished with value: 0.714463400206645 and parameters: {'max_depth': 8, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 4.171082992707598, 'alpha': 0.3483013957282992, 'lambda': 2.855798167695794}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  20%|██        | 40/200 [27:27<1:19:52][I 2024-10-06 05:52:40,442] Trial 40 finished with value: 0.71433563439342 and parameters: {'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7, 'subsample': 0.8, 'gamma': 2.949625071399242, 'alpha': 1.1650466579004553, 'lambda': 2.6865919391363757}. Best is trial 32 with value: 0.7130877900150618.
# Optuna Optimization:  20%|██        | 41/200 [28:02<1:23:18][I 2024-10-06 05:53:24,676] Trial 41 finished with value: 0.7123761651422195 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'colsample_bytree': 0.5, 'subsample': 0.9, 'gamma': 2.578843800000838, 'alpha': 0.9000047092005353, 'lambda': 2.2967798267458654}. Best is trial 41 with value: 0.7123761651422195.
# Optuna Optimization:  21%|██        | 42/200 [28:46<1:32:53][I 2024-10-06 05:54:03,500] Trial 42 finished with value: 0.7130935562541616 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'colsample_bytree': 0.5, 'subsample': 0.8, 'gamma': 3.3305857341179337, 'alpha': 0.8529599499549697, 'lambda': 2.3952898161983294}. Best is trial 41 with value: 0.7123761651422195.
# Optuna Optimization:  22%|██▏       | 43/200 [29:25<1:35:05][I 2024-10-06 05:54:32,410] Trial 43 finished with value: 0.715286119514365 and parameters: {'max_depth': 7, 'min_child_weight': 14, 'colsample_bytree': 0.5, 'subsample': 0.9, 'gamma': 3.892430862948391, 'alpha': 0.5049989059549727, 'lambda': 2.4688204735816464}. Best is trial 41 with value: 0.7123761651422195.
# Optuna Optimization:  22%|██▏       | 44/200 [29:54<1:28:41][I 2024-10-06 05:55:06,256] Trial 44 finished with value: 0.7161274539791544 and parameters: {'max_depth': 8, 'min_child_weight': 13, 'colsample_bytree': 0.5, 'subsample': 1.0, 'gamma': 3.587931602524465, 'alpha': 0.5950449945011587, 'lambda': 2.73544884598766}. Best is trial 41 with value: 0.7123761651422195.
# Optuna Optimization:  22%|██▎       | 45/200 [30:28<1:27:54][I 2024-10-06 05:55:52,638] Trial 45 finished with value: 0.7123014646586364 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.7059023753138876, 'alpha': 0.8841973024761353, 'lambda': 2.595912601535888}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  23%|██▎       | 46/200 [31:14<1:36:51][I 2024-10-06 05:56:38,718] Trial 46 finished with value: 0.715468524741352 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.7, 'subsample': 0.6, 'gamma': 2.65828849263397, 'alpha': 0.8358522958381441, 'lambda': 2.6222910201862404}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  24%|██▎       | 47/200 [32:00<1:42:36][I 2024-10-06 05:57:18,103] Trial 47 finished with value: 0.7126283950103783 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0029662900575267, 'alpha': 0.6576748725873627, 'lambda': 2.8283225978472353}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  24%|██▍       | 48/200 [32:39<1:41:17][I 2024-10-06 05:58:05,040] Trial 48 finished with value: 0.7132366256537249 and parameters: {'max_depth': 8, 'min_child_weight': 7, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.404040907389343, 'alpha': 0.6347078354590259, 'lambda': 2.1728176892730198}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  24%|██▍       | 49/200 [33:26<1:45:52][I 2024-10-06 05:59:06,509] Trial 49 finished with value: 0.7160538139025129 and parameters: {'max_depth': 9, 'min_child_weight': 10, 'colsample_bytree': 0.8, 'subsample': 0.7, 'gamma': 1.679590842455708, 'alpha': 0.2019608187520795, 'lambda': 2.417689204861984}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  25%|██▌       | 50/200 [34:28<1:59:43][I 2024-10-06 05:59:45,028] Trial 50 finished with value: 0.717371421490417 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'colsample_bytree': 0.7, 'subsample': 0.5, 'gamma': 3.0483750923265043, 'alpha': 0.3417976888221608, 'lambda': 2.79122857172225}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  26%|██▌       | 51/200 [35:06<1:51:56][I 2024-10-06 06:00:18,442] Trial 51 finished with value: 0.713409370083528 and parameters: {'max_depth': 7, 'min_child_weight': 12, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.879124260766025, 'alpha': 0.8531939111563361, 'lambda': 2.623379481374877}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  26%|██▌       | 52/200 [35:40<1:42:33][I 2024-10-06 06:00:54,818] Trial 52 finished with value: 0.7124338170862035 and parameters: {'max_depth': 8, 'min_child_weight': 14, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.289825037850899, 'alpha': 0.7015994675910892, 'lambda': 2.8667439079976167}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  26%|██▋       | 53/200 [36:16<1:38:02][I 2024-10-06 06:01:35,631] Trial 53 finished with value: 0.7137399230325687 and parameters: {'max_depth': 8, 'min_child_weight': 10, 'colsample_bytree': 0.6, 'subsample': 0.6, 'gamma': 2.6430455566740982, 'alpha': 0.9249463541011882, 'lambda': 2.76266113198368}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  27%|██▋       | 54/200 [36:57<1:37:57][I 2024-10-06 06:02:14,475] Trial 54 finished with value: 0.712729941270588 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.3213689171562124, 'alpha': 1.1057565800093572, 'lambda': 2.3123567680703028}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  28%|██▊       | 55/200 [37:36<1:36:15][I 2024-10-06 06:03:02,967] Trial 55 finished with value: 0.7131485743938006 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.3899900661304474, 'alpha': 1.0877161580499517, 'lambda': 2.0592256700987903}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  28%|██▊       | 56/200 [38:24<1:41:50][I 2024-10-06 06:03:42,864] Trial 56 finished with value: 0.7130357453392066 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.2000529852849793, 'alpha': 1.1869219966348479, 'lambda': 2.5571338939111214}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  28%|██▊       | 57/200 [39:04<1:39:18][I 2024-10-06 06:04:24,850] Trial 57 finished with value: 0.7149368526092733 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.7, 'subsample': 0.6, 'gamma': 3.203693088870243, 'alpha': 1.2735182849426492, 'lambda': 2.2817080319891225}. Best is trial 45 with value: 0.7123014646586364.
# Optuna Optimization:  29%|██▉       | 58/200 [39:46<1:38:50][I 2024-10-06 06:05:09,092] Trial 58 finished with value: 0.7121220804654832 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma':
. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  49%|████▉     | 98/200 [1:08:52<1:09:50][I 2024-10-06 06:34:09,505] Trial 98 finished with value: 0.7128830767849538 and parameters: {'max_depth': 9, 'min_child_weight': 22, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.5111731245446864, 'alpha': 0.0008269785328061108, 'lambda': 0.746167289259226}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  50%|████▉     | 99/200 [1:09:31<1:07:54][I 2024-10-06 06:34:54,204] Trial 99 finished with value: 0.71194953457091 and parameters: {'max_depth': 9, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.131347421335904, 'alpha': 0.13058480202028708, 'lambda': 0.9740710082819153}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  50%|█████     | 100/200 [1:10:16<1:09:24][I 2024-10-06 06:35:36,349] Trial 100 finished with value: 0.7147673465692927 and parameters: {'max_depth': 9, 'min_child_weight': 23, 'colsample_bytree': 0.5, 'subsample': 0.6, 'gamma': 2.9488261612742503, 'alpha': 0.2651560375206714, 'lambda': 0.9720156251030319}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  50%|█████     | 101/200 [1:10:58<1:08:57][I 2024-10-06 06:36:18,169] Trial 101 finished with value: 0.7120247323344258 and parameters: {'max_depth': 9, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.15719958860873, 'alpha': 0.14664058766046495, 'lambda': 1.1093380087170237}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  51%|█████     | 102/200 [1:11:40<1:08:16][I 2024-10-06 06:37:00,014] Trial 102 finished with value: 0.7127402562316342 and parameters: {'max_depth': 9, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.149341703174258, 'alpha': 0.16586493346379272, 'lambda': 1.1045678454045278}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  52%|█████▏    | 103/200 [1:12:21<1:07:36][I 2024-10-06 06:37:43,672] Trial 103 finished with value: 0.7127584834770894 and parameters: {'max_depth': 9, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.966369914214509, 'alpha': 0.3459358565431896, 'lambda': 0.8525581309483904}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  52%|█████▏    | 104/200 [1:13:05<1:07:47][I 2024-10-06 06:38:32,463] Trial 104 finished with value: 0.7129412698731429 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.5862982915728745, 'alpha': 0.15246485022916428, 'lambda': 1.3803319338229012}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  52%|█████▎    | 105/200 [1:13:54<1:10:08][I 2024-10-06 06:39:19,832] Trial 105 finished with value: 0.712022835070755 and parameters: {'max_depth': 10, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.107474888321777, 'alpha': 0.2900958024577127, 'lambda': 1.2103733653996687}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  53%|█████▎    | 106/200 [1:14:41<1:10:50][I 2024-10-06 06:40:05,917] Trial 106 finished with value: 0.712778853985569 and parameters: {'max_depth': 10, 'min_child_weight': 23, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.1833742371405718, 'alpha': 0.20594722969731225, 'lambda': 1.151574784689033}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  54%|█████▎    | 107/200 [1:15:27<1:10:29][I 2024-10-06 06:40:46,741] Trial 107 finished with value: 0.7137299571216639 and parameters: {'max_depth': 10, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.5633990326899867, 'alpha': 0.38473090245363384, 'lambda': 1.0158702617089428}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  54%|█████▍    | 108/200 [1:16:08<1:07:35][I 2024-10-06 06:41:34,819] Trial 108 finished with value: 0.7130003456837816 and parameters: {'max_depth': 10, 'min_child_weight': 22, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.0651153619000024, 'alpha': 0.08260984330505539, 'lambda': 0.9195759848810101}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  55%|█████▍    | 109/200 [1:16:56<1:08:40][I 2024-10-06 06:42:19,932] Trial 109 finished with value: 0.7122526491940812 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.860504892620126, 'alpha': 0.27978341840540044, 'lambda': 1.291419599994575}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  55%|█████▌    | 110/200 [1:17:41<1:07:50][I 2024-10-06 06:43:04,565] Trial 110 finished with value: 0.712845142383242 and parameters: {'max_depth': 10, 'min_child_weight': 19, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.3240334012344195, 'alpha': 0.30782120689836556, 'lambda': 1.284892825019401}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  56%|█████▌    | 111/200 [1:18:26<1:06:49][I 2024-10-06 06:43:49,766] Trial 111 finished with value: 0.7124583125425988 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.871134555035432, 'alpha': 0.1335893046501186, 'lambda': 1.2076369914575789}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  56%|█████▌    | 112/200 [1:19:11<1:06:08][I 2024-10-06 06:44:28,811] Trial 112 finished with value: 0.7132294418700926 and parameters: {'max_depth': 9, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.4214793907123227, 'alpha': 0.26141773405971536, 'lambda': 0.8160409608248808}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  56%|█████▋    | 113/200 [1:19:50<1:02:45][I 2024-10-06 06:45:12,226] Trial 113 finished with value: 0.7123312931684096 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.016014794722498, 'alpha': 0.4018721141898627, 'lambda': 1.3656652549277108}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  57%|█████▋    | 114/200 [1:20:34<1:02:05][I 2024-10-06 06:45:55,049] Trial 114 finished with value: 0.7120924689125897 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.0840645968658773, 'alpha': 0.3946023811477399, 'lambda': 1.3928588705104694}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  57%|█████▊    | 115/200 [1:21:16<1:01:09][I 2024-10-06 06:46:36,035] Trial 115 finished with value: 0.7125414919013541 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.22214665935442, 'alpha': 0.46266719797684636, 'lambda': 1.6457300080217199}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  58%|█████▊    | 116/200 [1:21:57<59:31]  [I 2024-10-06 06:47:20,842] Trial 116 finished with value: 0.7132712243361536 and parameters: {'max_depth': 10, 'min_child_weight': 22, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.119390489371262, 'alpha': 0.31371015656145046, 'lambda': 1.2839705245216753}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  58%|█████▊    | 117/200 [1:22:42<59:45][I 2024-10-06 06:48:04,759] Trial 117 finished with value: 0.7124213857214774 and parameters: {'max_depth': 9, 'min_child_weight': 23, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.7953521463334363, 'alpha': 0.046490197775887254, 'lambda': 1.4797261055315256}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  59%|█████▉    | 118/200 [1:23:26<59:20][I 2024-10-06 06:48:57,400] Trial 118 finished with value: 0.7129816721623551 and parameters: {'max_depth': 10, 'min_child_weight': 19, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.721217673869913, 'alpha': 0.3980504773661382, 'lambda': 1.4348477021879897}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  60%|█████▉    | 119/200 [1:24:19<1:02:20][I 2024-10-06 06:49:40,931] Trial 119 finished with value: 0.7120348247100735 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.0080530713253992, 'alpha': 0.20733974048694692, 'lambda': 0.7843015594365452}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  60%|██████    | 120/200 [1:25:02<1:00:31][I 2024-10-06 06:50:32,188] Trial 120 finished with value: 0.7127519608395946 and parameters: {'max_depth': 11, 'min_child_weight': 21, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.0147777546161496, 'alpha': 0.2089357119072324, 'lambda': 0.7856850925259161}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  60%|██████    | 121/200 [1:25:54<1:02:04][I 2024-10-06 06:51:11,951] Trial 121 finished with value: 0.7130063665153757 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.246587715387746, 'alpha': 0.292256950290268, 'lambda': 1.019526943228141}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  61%|██████    | 122/200 [1:26:33<58:24]  [I 2024-10-06 06:51:54,455] Trial 122 finished with value: 0.7124975810904828 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 3.1003434982879123, 'alpha': 0.23772765700775736, 'lambda': 0.6755891165762123}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  62%|██████▏   | 123/200 [1:27:16<56:43][I 2024-10-06 06:52:38,300] Trial 123 finished with value: 0.7130009686410613 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.5, 'subsample': 0.7, 'gamma': 2.9224138466796092, 'alpha': 0.6111007514676893, 'lambda': 0.9160988862475443}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  62%|██████▏   | 124/200 [1:28:00<55:51][I 2024-10-06 06:53:26,423] Trial 124 finished with value: 0.7120320102812103 and parameters: {'max_depth': 10, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.34515238361917, 'alpha': 0.4461384000069211, 'lambda': 0.7151594939079429}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  62%|██████▎   | 125/200 [1:28:48<56:37][I 2024-10-06 06:54:09,762] Trial 125 finished with value: 0.7128487873204766 and parameters: {'max_depth': 10, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.4023455502085778, 'alpha': 0.3390924895717919, 'lambda': 0.618972628827836}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:
. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  84%|████████▍ | 168/200 [1:59:48<21:33][I 2024-10-06 07:25:13,558] Trial 168 finished with value: 0.7122797075360771 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.8189601377528604, 'alpha': 0.06652755627005373, 'lambda': 0.5102853914323846}. Best is trial 63 with value: 0.7116533507897514.
# Optuna Optimization:  84%|████████▍ | 169/200 [2:00:35<21:50][I 2024-10-06 07:25:56,098] Trial 169 finished with value: 0.711005503694219 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.227614368838558, 'alpha': 0.1381184475569871, 'lambda': 0.6671661482124529}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  85%|████████▌ | 170/200 [2:01:17<21:10][I 2024-10-06 07:26:37,342] Trial 170 finished with value: 0.7147226417562225 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.9, 'subsample': 0.7, 'gamma': 3.2373649500326938, 'alpha': 2.1316933701673495, 'lambda': 0.6554009364358778}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  86%|████████▌ | 171/200 [2:01:59<20:18][I 2024-10-06 07:27:16,207] Trial 171 finished with value: 0.7135155628437733 and parameters: {'max_depth': 9, 'min_child_weight': 27, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.013928699142306, 'alpha': 0.13941510792150574, 'lambda': 0.5342760324731062}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  86%|████████▌ | 172/200 [2:02:38<19:10][I 2024-10-06 07:28:00,092] Trial 172 finished with value: 0.7118284111868994 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0863030367532343, 'alpha': 0.1883793398788715, 'lambda': 0.474720816436177}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  86%|████████▋ | 173/200 [2:03:21<18:51][I 2024-10-06 07:28:44,506] Trial 173 finished with value: 0.7114374652731859 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0512020285448735, 'alpha': 0.25780460277177597, 'lambda': 0.4323829699642028}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  87%|████████▋ | 174/200 [2:04:06<18:29][I 2024-10-06 07:29:30,729] Trial 174 finished with value: 0.7122506994336438 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.867433742755163, 'alpha': 0.06552230024144035, 'lambda': 0.4266542107956516}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  88%|████████▊ | 175/200 [2:04:52<18:13][I 2024-10-06 07:30:14,232] Trial 175 finished with value: 0.7118828257019395 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0355335186527617, 'alpha': 0.2003636807731108, 'lambda': 0.29703701108039615}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  88%|████████▊ | 176/200 [2:05:36<17:27][I 2024-10-06 07:30:58,758] Trial 176 finished with value: 0.7121308975427066 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0418962340436795, 'alpha': 0.18493631557497217, 'lambda': 0.34033189064165714}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  88%|████████▊ | 177/200 [2:06:20<16:50][I 2024-10-06 07:31:38,892] Trial 177 finished with value: 0.7124531345602713 and parameters: {'max_depth': 9, 'min_child_weight': 19, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.2372571475997947, 'alpha': 0.23258000011956764, 'lambda': 0.4555721406572907}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  89%|████████▉ | 178/200 [2:07:00<15:41][I 2024-10-06 07:32:19,675] Trial 178 finished with value: 0.7122472838810896 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.412225850832474, 'alpha': 0.09841959910295427, 'lambda': 0.2608519299723304}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  90%|████████▉ | 179/200 [2:07:41<14:45][I 2024-10-06 07:33:03,533] Trial 179 finished with value: 0.7118940968893696 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.081174470117288, 'alpha': 0.05533390555589979, 'lambda': 0.3527697940033492}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  90%|█████████ | 180/200 [2:08:25<14:13][I 2024-10-06 07:33:44,322] Trial 180 finished with value: 0.7127589166549405 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.175350488441612, 'alpha': 0.2674882559788601, 'lambda': 0.30584103340307706}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  90%|█████████ | 181/200 [2:09:06<13:20][I 2024-10-06 07:34:29,341] Trial 181 finished with value: 0.7116739108808927 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.092210315535446, 'alpha': 0.03826904545155313, 'lambda': 0.35862622968593993}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  91%|█████████ | 182/200 [2:09:51<12:53][I 2024-10-06 07:35:10,882] Trial 182 finished with value: 0.7120383442775733 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.2995326846930646, 'alpha': 0.012004592875904302, 'lambda': 0.4291731857672476}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  92%|█████████▏| 183/200 [2:10:32<12:03][I 2024-10-06 07:35:56,859] Trial 183 finished with value: 0.711669397186415 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.124989561660609, 'alpha': 0.12215616435562732, 'lambda': 0.3693405757993238}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  92%|█████████▏| 184/200 [2:11:18<11:37][I 2024-10-06 07:36:44,191] Trial 184 finished with value: 0.7122354083584042 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.731193674208686, 'alpha': 0.18175225963801028, 'lambda': 0.38188592141715727}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  92%|█████████▎| 185/200 [2:12:06<11:10][I 2024-10-06 07:37:32,008] Trial 185 finished with value: 0.7114649689460159 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.974397321165281, 'alpha': 0.12861863233282594, 'lambda': 0.2576278471336245}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  93%|█████████▎| 186/200 [2:12:53<10:38][I 2024-10-06 07:38:19,050] Trial 186 finished with value: 0.7116077406368545 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.9241484326880056, 'alpha': 0.12394018325016819, 'lambda': 0.24561174799605062}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  94%|█████████▎| 187/200 [2:13:40<09:58][I 2024-10-06 07:39:04,731] Trial 187 finished with value: 0.7119865683542181 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.8449399608513857, 'alpha': 0.19481841919548992, 'lambda': 0.25089729405365246}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  94%|█████████▍| 188/200 [2:14:26<09:11][I 2024-10-06 07:39:49,630] Trial 188 finished with value: 0.7122813617794456 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.9641320688363506, 'alpha': 0.2624407463474166, 'lambda': 0.3160894351101994}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  94%|█████████▍| 189/200 [2:15:11<08:21][I 2024-10-06 07:40:35,926] Trial 189 finished with value: 0.7119949512261389 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.9576368989927038, 'alpha': 0.1707369652223711, 'lambda': 0.20207404991532946}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  95%|█████████▌| 190/200 [2:15:57<07:38][I 2024-10-06 07:41:21,141] Trial 190 finished with value: 0.7135472880813551 and parameters: {'max_depth': 9, 'min_child_weight': 18, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.640678068823711, 'alpha': 1.7400928251239933, 'lambda': 0.09621923684684175}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  96%|█████████▌| 191/200 [2:16:43<06:50][I 2024-10-06 07:42:05,307] Trial 191 finished with value: 0.7115814737522049 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.052943614241021, 'alpha': 0.11436431645839867, 'lambda': 0.341159136005234}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  96%|█████████▌| 192/200 [2:17:27<06:01][I 2024-10-06 07:42:53,629] Trial 192 finished with value: 0.7114730126802584 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.8558368167394335, 'alpha': 0.10374518256096192, 'lambda': 0.36522647038171063}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  96%|█████████▋| 193/200 [2:18:15<05:22][I 2024-10-06 07:43:41,067] Trial 193 finished with value: 0.7120140092032959 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.7836312225385997, 'alpha': 0.09728169641957883, 'lambda': 0.35144164274053613}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  97%|█████████▋| 194/200 [2:19:02<04:39][I 2024-10-06 07:44:25,489] Trial 194 finished with value: 0.7116965807915636 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0466033007720847, 'alpha': 0.11663457365943923, 'lambda': 0.2552204679349232}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  98%|█████████▊| 195/200 [2:19:47<03:49][I 2024-10-06 07:45:11,207] Trial 195 finished with value: 0.7114551913073047 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.062793827203526, 'alpha': 0.13015333381087513, 'lambda': 0.2713247641835723}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  98%|█████████▊| 196/200 [2:20:33<03:03][I 2024-10-06 07:45:56,264] Trial 196 finished with value: 0.7118647715900848 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 3.0428214322797613, 'alpha': 0.13699133443527478, 'lambda': 0.24469162921545196}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  98%|█████████▊| 197/200 [2:21:18<02:16][I 2024-10-06 07:46:42,416] Trial 197 finished with value: 0.7121109732659257 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.968759755522331, 'alpha': 0.13904257524134647, 'lambda': 0.16546009081784152}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization:  99%|█████████▉| 198/200 [2:22:04<01:31][I 2024-10-06 07:47:29,774] Trial 198 finished with value: 0.7114381277691447 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.735584119054373, 'alpha': 0.3003480163029543, 'lambda': 0.2518114826263695}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization: 100%|█████████▉| 199/200 [2:22:51<00:46][I 2024-10-06 07:48:17,314] Trial 199 finished with value: 0.7120207241404759 and parameters: {'max_depth': 9, 'min_child_weight': 17, 'colsample_bytree': 0.6, 'subsample': 0.7, 'gamma': 2.7357016881285467, 'alpha': 0.18697364178946532, 'lambda': 0.2462703864837452}. Best is trial 169 with value: 0.711005503694219.
# Optuna Optimization: 100%|██████████| 200/200 [2:23:39<00:00]

# %%
print("Best trial:")
trial = study.best_trial

print(f"  Value: {trial.value}")
print("  Params:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# Best trial:
#   Value: 0.711005503694219
#   Params:
#     max_depth: 9
#     min_child_weight: 19
#     colsample_bytree: 0.6
#     subsample: 0.7
#     gamma: 3.227614368838558
#     alpha: 0.1381184475569871
#     lambda: 0.6671661482124529

# %% [markdown]
# Train the XGBoost model using the best hyperparameters found by Optuna, then save the trained model for future use.

# %%
xgb_params = {
    'objective': 'multi:softprob',
    'num_class': 3,
    'eval_metric': 'mlogloss',
    'max_depth': 9,
    'min_child_weight': 19,
    'learning_rate': 0.01,
    'colsample_bytree': 0.6,
    'subsample': 0.7,
    'gamma': 3.227614368838558,
    'alpha': 0.1381184475569871,
    'lambda': 0.6671661482124529,
    'tree_method': 'hist',
    'random_state': 97,
    'verbosity': 1,
    'device': "cuda"
    }

# xgb_params = {
#     'objective': 'multi:softprob',
#     'num_class': 3,
#     'eval_metric': 'mlogloss',
#     'max_depth': 6,
#     'min_child_weight': 12,
#     'learning_rate': 0.01,
#     'colsample_bytree': 0.6,
#     'subsample': 0.8,
#     'tree_method': 'hist',
#     'random_state': 97,
#     'verbosity': 1,
#     'device': "cuda"
#     }

evals = [(dtrain, 'train'), (dval, 'validation')]
model = xgb.train(params = xgb_params,
                  dtrain = dtrain,
                  evals = evals,
                  num_boost_round = 2000,
                  early_stopping_rounds = 20,
                  verbose_eval = 100)
# Out:
# [0]	train-mlogloss:1.09374	validation-mlogloss:1.09471
# [100]	train-mlogloss:0.78656	validation-mlogloss:0.86872
# [200]	train-mlogloss:0.65126	validation-mlogloss:0.78695
# [300]	train-mlogloss:0.57729	validation-mlogloss:0.75054
# [400]	train-mlogloss:0.53113	validation-mlogloss:0.73245
# [500]	train-mlogloss:0.49989	validation-mlogloss:0.72318
# [600]	train-mlogloss:0.47744	validation-mlogloss:0.71787
# [700]	train-mlogloss:0.46106	validation-mlogloss:0.71492
# [800]	train-mlogloss:0.44902	validation-mlogloss:0.71302
# [900]	train-mlogloss:0.44079	validation-mlogloss:0.71188
# [1000]	train-mlogloss:0.43490	validation-mlogloss:0.71136
# [1100]	train-mlogloss:0.42996	validation-mlogloss:0.71103
# [1106]	train-mlogloss:0.42980	validation-mlogloss:0.71104

# %%
#model.save_model(BASIC_PATH+MODEL_PATH+'xgboost_model.json')

# %%
xgb_model = xgb.Booster()
xgb_model.load_model(BASIC_PATH+MODEL_PATH+'xgboost_model.json')

# %%
holdout_probs = xgb_model.predict(holdout)
holdout_preds = holdout_probs.argmax(-1)
Counter(holdout_preds)
# Out:
# Counter({0: 3686, 2: 722, 1: 1513})

# %%
test_probs = xgb_model.predict(test)
test_preds = test_probs.argmax(-1)
Counter(test_preds)
# Out:
# Counter({0: 4524, 2: 921, 1: 1937})

# %%
print('Holdout metrics:')
print(f"Loss: {log_loss(holdout_data[TARGET], holdout_probs)}")
print(f"Precision: {precision_score(holdout_data[TARGET], holdout_preds, average = 'macro')}")
print(f"Recall: {recall_score(holdout_data[TARGET], holdout_preds, average = 'macro')}")
print(f"F1: {f1_score(holdout_data[TARGET], holdout_preds, average = 'macro')}")

print('='*50)

print('Test metrics:')
print(f"Loss: {log_loss(test_data[TARGET], test_probs)}")
print(f"Precision: {precision_score(test_data[TARGET], test_preds, average = 'macro')}")
print(f"Recall: {recall_score(test_data[TARGET], test_preds, average = 'macro')}")
print(f"F1: {f1_score(test_data[TARGET], test_preds, average = 'macro')}")
# Out:
# Holdout metrics:
# Loss: 0.676053684247363
# Precision: 0.6661420733276419
# Recall: 0.6303884310539692
# F1: 0.6426847596681292
# ==================================================
# Test metrics:
# Loss: 0.6884532609462317
# Precision: 0.6384198976741872
# Recall: 0.6133063349087662
# F1: 0.6217734187893583

# %% [markdown]
# We will retain some of the key text features and append the XGBoost model predictions to the holdout and test datasets. The updated datasets will then be saved for future use in training a second-level model.

# %%
COLS_TO_DROP = [col for col in holdout_data.columns if 'emb' in col]

# %%
holdout_data['1st_level_xgb_preds'] = holdout_preds
test_data['1st_level_xgb_preds'] = test_preds

# %%
holdout_data.drop(COLS_TO_DROP, axis = 1, inplace = True)
test_data.drop(COLS_TO_DROP, axis = 1, inplace = True)

# %%
# holdout_data.to_csv(BASIC_PATH+SAVE_DATASETS_FOLDER+'holdout_1st_level_xgb_preds.csv', index = False)
# test_data.to_csv(BASIC_PATH+SAVE_DATASETS_FOLDER+'test_1st_level_xgb_preds.csv', index = False)
